# %% [markdown]
# # preliminary data analysis

# %%
import pandas as pd

# %%
dtype_games_details = {
    'GAME_ID': int,
    'TEAM_ID': int,
    'TEAM_ABBREVIATION': str,
    'TEAM_CITY': str,
    'PLAYER_ID': int,
    'PLAYER_NAME': str,
    'NICKNAME': str,
    'START_POSITION': str,
    'COMMENT': str,
    'MIN': str,  # You may want to handle this as time or float after cleaning
    'FGM': float,
    'FGA': float,
    'FG_PCT': float,
    'FG3M': float,
    'FG3A': float,
    'FG3_PCT': float,
    'FTM': float,
    'FTA': float,
    'FT_PCT': float,
    'OREB': float,
    'DREB': float,
    'REB': float,
    'AST': float,
    'STL': float,
    'BLK': float,
    'TO': float,
    'PF': float,
    'PTS': float,
    'PLUS_MINUS': float
}

dtype_games = {
    'GAME_DATE_EST': str,
    'GAME_ID': int,
    'GAME_STATUS_TEXT': str,
    'HOME_TEAM_ID': int,
    'VISITOR_TEAM_ID': int,
    'SEASON': int,
    'TEAM_ID_home': int,
    'PTS_home': float,
    'FG_PCT_home': float,
    'FT_PCT_home': float,
    'FG3_PCT_home': float,
    'AST_home': float,
    'REB_home': float,
    'TEAM_ID_away': int,
    'PTS_away': float,
    'FG_PCT_away': float,
    'FT_PCT_away': float,
    'FG3_PCT_away': float,
    'AST_away': float,
    'REB_away': float,
    'HOME_TEAM_WINS': int
}

dtype_players = {
    'PLAYER_NAME': str,
    'TEAM_ID': int,
    'PLAYER_ID': int,
    'SEASON': int
}

dtype_rankings = {
    'TEAM_ID': int,
    'LEAGUE_ID': int,
    'SEASON_ID': int,
    'STANDINGSDATE': str,
    'CONFERENCE': str,
    'TEAM': str,
    'G': int,
    'W': int,
    'L': int,
    'W_PCT': float,
    'HOME_RECORD': str,
    'ROAD_RECORD': str,
    'RETURNTOPLAY': float
}

dtype_teams = {
    'LEAGUE_ID': int,
    'TEAM_ID': int,
    'MIN_YEAR': int,
    'MAX_YEAR': int,
    'ABBREVIATION': str,
    'NICKNAME': str,
    'YEARFOUNDED': int,
    'CITY': str,
    'ARENA': str,
    'ARENACAPACITY': float,
    'OWNER': str,
    'GENERALMANAGER': str,
    'HEADCOACH': str,
    'DLEAGUEAFFILIATION': str
}

# %%
# import all datasets

games_details = pd.read_csv('data/games_details.csv', dtype = dtype_games_details)
games = pd.read_csv('data/games.csv', dtype = dtype_games)
players = pd.read_csv('data/players.csv', dtype = dtype_players)
ranking = pd.read_csv('data/ranking.csv', dtype = dtype_rankings)
teams = pd.read_csv('data/teams.csv', dtype = dtype_teams)

# %%
games_details
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0       22200477  1610612759               SAS  San Antonio    1629641
# 1       22200477  1610612759               SAS  San Antonio    1631110
# 2       22200477  1610612759               SAS  San Antonio    1627751
# 3       22200477  1610612759               SAS  San Antonio    1630170
# 4       22200477  1610612759               SAS  San Antonio    1630200
# ...          ...         ...               ...          ...        ...
# 668623  11200005  1610612743               DEN       Denver     202706
# 668624  11200005  1610612743               DEN       Denver     202702
# 668625  11200005  1610612743               DEN       Denver     201585
# 668626  11200005  1610612743               DEN       Denver     202389
# 668627  11200005  1610612743               DEN       Denver     201951
#
#             PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  OREB  \
# ...

# %%
games.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2022-12-22  22200477            Final    1610612740       1610612759
# 1    2022-12-22  22200478            Final    1610612762       1610612764
# 2    2022-12-21  22200466            Final    1610612739       1610612749
# 3    2022-12-21  22200467            Final    1610612755       1610612765
# 4    2022-12-21  22200468            Final    1610612737       1610612741
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2022    1610612740     126.0        0.484        0.926  ...      25.0
# 1    2022    1610612762     120.0        0.488        0.952  ...      16.0
# 2    2022    1610612739     114.0        0.482        0.786  ...      22.0
# 3    2022    1610612755     113.0        0.441        0.909  ...      27.0
# 4    2022    1610612737     108.0        0.429        1.000  ...      22.0
#
# ...

# %%
players.head()
# Out:
#         PLAYER_NAME     TEAM_ID  PLAYER_ID  SEASON
# 0     Royce O'Neale  1610612762    1626220    2019
# 1  Bojan Bogdanovic  1610612762     202711    2019
# 2       Rudy Gobert  1610612762     203497    2019
# 3  Donovan Mitchell  1610612762    1628378    2019
# 4       Mike Conley  1610612762     201144    2019

# %%
ranking.head()
# Out:
#       TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE         TEAM   G  \
# 0  1610612743          0      22022    2022-12-22       West       Denver  30
# 1  1610612763          0      22022    2022-12-22       West      Memphis  30
# 2  1610612740          0      22022    2022-12-22       West  New Orleans  31
# 3  1610612756          0      22022    2022-12-22       West      Phoenix  32
# 4  1610612746          0      22022    2022-12-22       West  LA Clippers  33
#
#     W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0  19  11  0.633        10-3         9-8           NaN
# 1  19  11  0.633        13-2         6-9           NaN
# 2  19  12  0.613        13-4         6-8           NaN
# 3  19  13  0.594        14-4         5-9           NaN
# 4  19  14  0.576        11-7         8-7           NaN

# %%
teams.head()
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# 0          0  1610612737      1949      2019          ATL      Hawks
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# 0         1949      Atlanta          State Farm Arena        18729.0
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# ...

# %%
# Check the sizes of all loaded datasets and display them
games_details_size = games_details.shape
games_size = games.shape
players_size = players.shape
ranking_size = ranking.shape
teams_size = teams.shape

sizes = {
    'games_details.csv': games_details_size,
    'games.csv': games_size,
    'players.csv': players_size,
    'ranking.csv': ranking_size,
    'teams.csv': teams_size
}

sizes
# Out:
# {'games_details.csv': (668628, 29),
#  'games.csv': (26651, 21),
#  'players.csv': (7228, 4),
#  'ranking.csv': (210342, 13),
#  'teams.csv': (30, 14)}

# %%
# Unite the datasets
# base is game_details (largest one)
# unite games_details and games on game_id
# then unite this to player on player_id
# unite teams and ranking on team_id 
# finally unite the latter to the rest based on team_id
merged_games = pd.merge(games_details, games, on=["GAME_ID"])
merged_teams_rankings = pd.merge(teams, ranking, how="outer", on=["TEAM_ID", "LEAGUE_ID"])

# %%
import sqlite3
conn = sqlite3.connect(":memory:")
merged_games_players.to_sql('table1', conn, index=False)
merged_teams_rankings.to_sql('table2', conn, index=False)
# Out:
# (669560, 49)

# %%
query = """
SELECT * FROM table1 
LEFT JOIN table2 ON table1.TEAM_ID = table2.TEAM_ID

UNION

SELECT * FROM table2 
LEFT JOIN table1 ON table1.TEAM_ID = table2.TEAM_ID
"""
merged_df = pd.read_sql_query(query, conn)


# The system crashes before managing to complete the merge
# Out:
# Index(['GAME_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_CITY', 'PLAYER_ID',
#        'PLAYER_NAME', 'NICKNAME', 'START_POSITION', 'COMMENT', 'MIN', 'FGM',
#        'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
#        'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS',
#        'PLUS_MINUS', 'GAME_DATE_EST', 'GAME_STATUS_TEXT', 'HOME_TEAM_ID',
#        'VISITOR_TEAM_ID', 'SEASON', 'TEAM_ID_home', 'PTS_home', 'FG_PCT_home',
#        'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home', 'TEAM_ID_away',
#        'PTS_away', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away',
#        'REB_away', 'HOME_TEAM_WINS'],
#       dtype='object')
